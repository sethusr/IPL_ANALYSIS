# %% [markdown]
# <div style="text-align: right">INFO 6105 Data Science Eng Methods and Tools</div>
# <div style="text-align: right">Professor Dino Konstantopoulos</div>

# %% [markdown]
# ## Final Project - IPL Data Analysis and Winner Prediction
# ### GROUP 1       <img src = 'images/logo.png' width=300 align = 'right'>
# <div style="text-align: left"><b>Mital Bhanushali - 002919890</b></div>
# <div style="text-align: left"><b>Prishaa Mittal - 002765340</b></div>
# <div style="text-align: left"><b>Sai Sravani Pillarisetty - 002722470</b></div>

# %% [markdown]
# # INDIAN PREMIERE LEAGUE
#
# The Indian Premier League (IPL) is a men's Twenty20 (T20) cricket league held annually in India and contested by ten city-based franchise teams. The league was founded by the Board of Control for Cricket in India in 2007.
#
# The IPL is the most popular cricket league in the world. In 2010, IPL became the first sporting event in the world to be broadcast live on YouTube. The brand value of the IPL in 2022 was ₹90,038 crore (US$11 billion).
# There have been fifteen seasons of the tournament. The current title holders are the Gujarat Titans, winning the 2022 edition by defeating Rajasthan Royals in the final game.
#
# <br />
# <img src="images/IPL2022.jpg" width=900 />

# %% [markdown]
# ## Importing the libraries

# %%
#import the libraries
import pandas as pd   #data analysis and manipulation package in the form data structure called data frame
import numpy as np    # to handle multidimensional data, scientific computation
import matplotlib.pyplot as plt   #for visualization
import warnings 
import seaborn as sns
sns.set_style('darkgrid')
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (14, 8)
warnings.filterwarnings('ignore', category=np.VisibleDeprecationWarning)

# %%
#importing modules and libraries
import statsmodels.api as sm
from datetime import datetime
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, cross_val_score, learning_curve, train_test_split
from sklearn.metrics import precision_score,roc_auc_score, recall_score, confusion_matrix, roc_curve, precision_recall_curve
import plotly.offline as py
py.init_notebook_mode(connected= True)
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.figure_factory as ff
import os
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Importing data

# %%
#Reading the CSV file and storing it in Pandas DataFrame

matches_df = pd.read_csv("archive\IPL_Matches_2008_2022.csv")
matches_df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
#Reading the CSV file and storing it in Pandas DataFrame
deliveries = pd.read_csv('archive/IPL_Ball_by_Ball_2008_2022.csv')

# %% [markdown]
# ## Cleaning the Data

# %%
#Standardizing the format of the 'Season' column in the DataFrame

matches_df.Season.replace({'2007/08': '2008', '2009/10': '2010', '2020/21': '2020'}, inplace =True)
print(matches_df.Season.unique())
# Out:
# ['2022' '2021' '2020' '2019' '2018' '2017' '2016' '2015' '2014' '2013'
#  '2012' '2011' '2010' '2009' '2008']

# %%
#Standardizing the format of the 'Venue' column in the DataFrame

matches_df.Venue.replace({'Arun Jaitley Stadium, Delhi': 'Arun Jaitley Stadium', 'Brabourne Stadium, Mumbai': 'Brabourne Stadium', 'Dr DY Patil Sports Academy, Mumbai': 'Dr DY Patil Sports Academy',
                         'Eden Gardens, Kolkata':'Eden Gardens','M.Chinnaswamy Stadium':'M Chinnaswamy Stadium','MA Chidambaram Stadium, Chepauk, Chennai':'MA Chidambaram Stadium','MA Chidambaram Stadium, Chepauk':'MA Chidambaram Stadium',
                         'Maharashtra Cricket Association Stadium, Pune':'Maharashtra Cricket Association Stadium','Punjab Cricket Association IS Bindra Stadium, Mohali':'Punjab Cricket Association IS Bindra Stadium',
                         'Punjab Cricket Association Stadium, Mohali':'Punjab Cricket Association IS Bindra Stadium','Rajiv Gandhi International Stadium, Uppal':'Rajiv Gandhi International Stadium','Wankhede Stadium, Mumbai':'Wankhede Stadium'}, inplace =True)
print(matches_df.Venue.unique())
# Out:
# ['Narendra Modi Stadium, Ahmedabad' 'Eden Gardens' 'Wankhede Stadium'
#  'Brabourne Stadium' 'Dr DY Patil Sports Academy'
#  'Maharashtra Cricket Association Stadium'
#  'Dubai International Cricket Stadium' 'Sharjah Cricket Stadium'
#  'Zayed Cricket Stadium, Abu Dhabi' 'Arun Jaitley Stadium'
#  'MA Chidambaram Stadium' 'Sheikh Zayed Stadium'
#  'Rajiv Gandhi International Stadium'
#  'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium'
#  'Punjab Cricket Association IS Bindra Stadium' 'M Chinnaswamy Stadium'
#  'Sawai Mansingh Stadium' 'Holkar Cricket Stadium' 'Feroz Shah Kotla'
#  'Green Park' 'Saurashtra Cricket Association Stadium'
#  'Shaheed Veer Narayan Singh International Stadium'
#  'JSCA International Stadium Complex' 'Sardar Patel Stadium, Motera'
#  'Barabati Stadium' 'Subrata Roy Sahara Stadium'
#  'Himachal Pradesh Cricket Association Stadium' 'Nehru Stadium'
#  'Vidarbha Cricket Association Stadium, Jamtha' 'New Wanderers Stadium'
# ...

# %%
#Correcting the inconsisitencies in the values of the City
matches_df.loc[matches_df['Venue'] == 'Dubai International Cricket Stadium', 'City'] = 'Dubai'
matches_df.loc[matches_df['Venue'] == 'Sharjah Cricket Stadium', 'City'] = 'Sharjah'

# %%
#Standardizing the format 
matches_df.Team1.replace({'Rising Pune Supergiant':'Rising Pune Supergiants'}, inplace = True)
matches_df.Team2.replace({'Rising Pune Supergiant':'Rising Pune Supergiants'}, inplace = True)
matches_df.TossWinner.replace({'Rising Pune Supergiant':'Rising Pune Supergiants'}, inplace = True)
matches_df.WinningTeam.replace({'Rising Pune Supergiant':'Rising Pune Supergiants'}, inplace = True)

# %%
#Converting the datatype from object to int
matches_df['Season'] = matches_df['Season'].astype(int)
#Displying the datatype of each column in the DataFrame
matches_df.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season               int32
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
matches_df['WinningTeam'].fillna('Draw',inplace=True)

# %% [markdown]
#  ***Finding the missing values*** :

# %%
'''Creating a bar plot using the Plotly library to visualize the amount 
of missing data in each column of the DataFrame. '''

from plotly.offline import iplot
#Creating a new DataFrame contains the count of the missing values for each column
null_feat = pd.DataFrame(len(matches_df['Venue']) - matches_df.isnull().sum(), columns = ['Count'])
#Creates a bar trace. 
#x parameter is for setting the index of the 'null-feat'
#y parameter is for setting the count of the missing values in each column
trace = go.Bar(x = null_feat.index, y = null_feat['Count'], opacity= 0.8, marker = dict(color = 'lightgrey', 
            line= dict(color= '#000000', width =1.5)))
#Creates a dictionary 'layout' that contains the title of the plot
layout = dict(title = "Missing Values")
#Creates a dictionary 'fig' that contains the trace and layout dictionaries
fig = dict(data = [trace], layout=layout)
py.iplot(fig)
# Out:
# <div>                            <div id="69fcb30d-7967-46a0-a8ae-aea2743a6029" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69fcb30d-7967-46a0-a8ae-aea2743a6029")) {                    Plotly.newPlot(                        "69fcb30d-7967-46a0-a8ae-aea2743a6029",                        [{"marker":{"color":"lightgrey","line":{"color":"#000000","width":1.5}},"opacity":0.8,"x":["ID","City","Date","Season","MatchNumber","Team1","Team2","Venue","TossWinner","TossDecision","SuperOver","WinningTeam","WonBy","Margin","method","Player_of_Match","Team1Players","Team2Players","Umpire1","Umpire2"],"y":[950,950,950,950,950,950,950,950,950,950,946,950,950,932,19,946,950,950,950,950],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"mar
# ...

# %%
'''Creating a new DF that contains information about the 
percentage of missing values in each column of the DF '''

missing_df = pd.DataFrame({
     #Checking which columns contain at least one missing value
    "Columns": matches_df.columns[matches_df.isnull().sum()>0],
    #Calculating the percentage of missing values for each of the selected columns
    "Values": matches_df[matches_df.columns[matches_df.isnull().sum()>0]].isnull().sum()/len(matches_df)*100
})
#Reseting the index to start from 0 and increment by 1 for each row
missing_df = missing_df.reset_index(drop=True)
#Display the values
missing_df
matches_df.isnull().sum()/len(matches_df)*100
# Out:
# ID                  0.000000
# City                0.000000
# Date                0.000000
# Season              0.000000
# MatchNumber         0.000000
# Team1               0.000000
# Team2               0.000000
# Venue               0.000000
# TossWinner          0.000000
# TossDecision        0.000000
# SuperOver           0.421053
# WinningTeam         0.000000
# WonBy               0.000000
# Margin              1.894737
# method             98.000000
# Player_of_Match     0.421053
# Team1Players        0.000000
# Team2Players        0.000000
# Umpire1             0.000000
# Umpire2             0.000000
# dtype: float64

# %%
#Removing the column 'method'
matches_df = matches_df.drop('method', axis=1)

# %%
'''
Installs the package 'sweetviz' 
Sweetviz" is a package for generating comprehensive exploratory data analysis
(EDA) reports in a single line of code. 
'''
pip install sweetviz --user
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import warnings

warnings.filterwarnings('ignore', category=np.VisibleDeprecationWarning)

# %%
import sweetviz as sv

my_report = sv.analyze(matches_df)
my_report.show_html()
# Out:
# Done! Use 'show' commands to display/save.   |█████████████████████████████████████████| [100%]   00:00 -> (00:00 left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # DATA VISUALIZATION

# %%
'''Generating a horizontal bar plot to visualize the number of matches 
played in each stadium '''
#Counts the number of occurences of each unique stadium name
ls=matches_df['Venue'].value_counts().sort_values(ascending=False)
#Creates a figure with size of 15 inches by 8 inches.
plt.figure(figsize=(15,8))
#Creating a horizontal bar plot using Seaborn's barplot() function
temp =sns.barplot(x=ls.index, y=ls.values, alpha=0.8)
#Title of the plot
plt.title('MOST PLAYED VENUE')
#Label of the y-axis
plt.ylabel('COUNT', fontsize=14)
#Label of the x-axis
plt.xlabel('NAME OF THE STADIUMS', fontsize=15)
#Rotate the z-axis labels by 90 degrees
temp.set_xticklabels(rotation=90,labels=ls.index,fontsize=10)
#Display the plot
plt.show()

# %% [markdown]
# ### Most number of places have been played at Wankhede Stadium
# <img src = 'images/wankhede.jpeg'>

# %%
# Filter for completed matches only
completed_matches = matches_df[matches_df['SuperOver'] == 'N']

# Filter for matches with valid results (batting first or batting second)
valid_results = completed_matches[(completed_matches['WinningTeam'] != 'NA') & (completed_matches['Margin'] > 0) & (completed_matches['Margin'] <= 250)]

# Group the data by venue, innings1 (Team1), and innings2 (Team2), and count the occurrences
grouped_data = valid_results.groupby(['Venue', 'Team1', 'Team2','WinningTeam']).size().reset_index(name='count')
# grouped_data

# Filter for only batting first or batting second win results
batting_first_wins = grouped_data[grouped_data['Team1'] == grouped_data['WinningTeam']]
batting_second_wins = grouped_data[grouped_data['Team2'] == grouped_data['WinningTeam']]

# Calculate total matches played, batting first wins, and batting second wins for each venue
total_matches_played = grouped_data.groupby('Venue')['count'].sum()
batting_first_wins_count = batting_first_wins.groupby('Venue')['count'].sum()
batting_second_wins_count = batting_second_wins.groupby('Venue')['count'].sum()

venues = total_matches_played.index
matches_played = total_matches_played.values
batting_first_wins = batting_first_wins_count.values
batting_second_wins = batting_second_wins_count.values

# Set up the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the total matches played, batting first wins, and batting second wins as bars
ax.bar(venues, matches_played, label='Total Matches Played')
ax.bar(venues, batting_first_wins, label='Batting First Wins')
ax.bar(venues, batting_second_wins, bottom=batting_first_wins, label='Batting Second Wins')

# Add labels and title
ax.set_xlabel('Venue')
ax.set_ylabel('Count')
ax.set_title('Total Matches Played, Batting First Wins, and Batting Second Wins by Venue')

# Add legend
ax.legend()

# Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %%
#Groups the 'Season' and 'Winning Team' columns
#Counts the number of occurences of each unique team with each season
teams_per_season = matches_df.groupby('Season')['WinningTeam'].value_counts()
#Displays the first 50 rows of team per season
teams_per_season.head(50)
# Out:
# Season  WinningTeam
# 2008    Rajasthan Royals               13
#         Kings XI Punjab                10
#         Chennai Super Kings             9
#         Delhi Daredevils                7
#         Mumbai Indians                  7
#         Kolkata Knight Riders           6
#         Royal Challengers Bangalore     4
#         Deccan Chargers                 2
# 2009    Delhi Daredevils               10
#         Deccan Chargers                 9
#         Royal Challengers Bangalore     9
#         Chennai Super Kings             8
#         Kings XI Punjab                 7
#         Rajasthan Royals                6
#         Mumbai Indians                  5
#         Kolkata Knight Riders           3
# 2010    Mumbai Indians                 11
#         Chennai Super Kings             9
#         Deccan Chargers                 8
#         Royal Challengers Bangalore     8
#         Delhi Daredevils                7
#         Kolkata Knight Riders           7
# ...

# %% [markdown]
# <img src = 'images/winners.jpg'>

# %%
#Creating empty lists ti store the year, teams and wins
years = []
teams = []
wins = []
#Iterating over each item where i is a tuple of the form (year,team) 
#v is the count of wins for that team in that year
for i, v in teams_per_season.iteritems():
    years.append(i[0])
    teams.append(i[1])
    wins.append(v)
#Creates a dictionary
data = {'Year': years,
        'Team': teams,
        'Wins': wins}
#Creates a new DF where each row represents a team's win count in a particular year
Year_wise_team_win = pd.DataFrame(data)

# %%
#Creating a bar plot to show the number of matches won by each team in each year
#Creates a figure size plot of 15 inches by 8 inches
plt.figure(figsize=(15,8))
#Creates a bar plot using Seaborn's barplot() function
temp =sns.barplot(x=Year_wise_team_win.Year, y=Year_wise_team_win.Wins, alpha=0.8,hue=Year_wise_team_win.Team, palette='Paired')
#Title of the plot
plt.title('Matches won by each Team ')
#Label for y-axis
plt.ylabel('COUNT', fontsize=14)
#Label for x-axis
plt.xlabel('YEAR', fontsize=15)
#Setting the alignment of the legend
plt.legend(loc='upper right')  # Move the hue legend to upper right corner
#plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
#Display the plot
plt.show()

# %%
year = 2008
#Creating a new DF with columns 'Year', 'Team', 'Wins'
winner_df = pd.DataFrame(columns = ['Year','Team','Wins'])
#Iterating through the teams_per_seasons
for i,v in teams_per_season.iteritems():  
#Checking if the year is equal to 2008
    if i[0] == year:
        #print(i[0])
#If yes, creates a new DF containing one row for year, team and number of wins for that teamm
        win_series = pd.DataFrame({
            'Year': [i[0]],
            'Team': [i[1]],
            'Wins': [v]
        })
#Using the append method to ensure that a new row is added
        winner_df = winner_df.append(win_series,ignore_index=True) 
        year = year+1
#Displying the DF
winner_df
# Out:
#     Year                   Team Wins
# 0   2008       Rajasthan Royals   13
# 1   2009       Delhi Daredevils   10
# 2   2010         Mumbai Indians   11
# 3   2011    Chennai Super Kings   11
# 4   2012  Kolkata Knight Riders   12
# 5   2013         Mumbai Indians   13
# 6   2014        Kings XI Punjab   12
# 7   2015    Chennai Super Kings   10
# 8   2016    Sunrisers Hyderabad   11
# 9   2017         Mumbai Indians   12
# 10  2018    Chennai Super Kings   11
# 11  2019         Mumbai Indians   11
# 12  2020         Mumbai Indians   11
# 13  2021    Chennai Super Kings   11
# 14  2022         Gujarat Titans   12

# %%
#Creates a figure bar plot size of 15 inches by 8 inches
plt.figure(figsize=(15,8))
temp =sns.barplot(x=winner_df.Year, y=winner_df.Wins, alpha=0.8,hue=winner_df.Team, palette='Paired')
#Title of the plot
plt.title('Highest number of match winning team each year ')
#Label for the y-axis
plt.ylabel('COUNT', fontsize=14)
#Label for the x-axis
plt.xlabel('Year', fontsize=15)
plt.legend(loc='upper right')  # Move the hue legend to upper right corner
#plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.show()

# %%
#Groups the year wise team wins
temp = Year_wise_team_win.groupby('Team')['Wins'].sum()#.sort_values(ascending=False))
temp
# Out:
# Team
# Chennai Super Kings            121
# Deccan Chargers                 29
# Delhi Capitals                  36
# Delhi Daredevils                67
# Draw                             4
# Gujarat Lions                   13
# Gujarat Titans                  12
# Kings XI Punjab                 88
# Kochi Tuskers Kerala             6
# Kolkata Knight Riders          114
# Lucknow Super Giants             9
# Mumbai Indians                 131
# Pune Warriors                   12
# Punjab Kings                    13
# Rajasthan Royals                96
# Rising Pune Supergiants         15
# Royal Challengers Bangalore    109
# Sunrisers Hyderabad             75
# Name: Wins, dtype: int64

# %%
#Creating a new DF which has columns for the team name and total number of wins across all years
Total_Matches_Won = pd.DataFrame(columns = ['Team','Wins'])
#Iterating through the 'temp' series
for i,v in temp.iteritems():    
    win_series = pd.DataFrame({
        'Team': [i],
        'Wins': [v]
        })
    Total_Matches_Won = Total_Matches_Won.append(win_series,ignore_index=True) 
        
Total_Matches_Won = Total_Matches_Won.sort_values(by='Wins', ascending=False)

# %%
#Create a pie chart using the plt.pie() function
plt.pie(Total_Matches_Won['Wins'], labels=Total_Matches_Won['Team'], autopct='%1.1f%%')
#Title of the chart
plt.title('Total Matches Won by Teams')
#Display the chart
plt.show()

# %%
# plt.figure(figsize=(10, 6))  # Set figure size
# sns.barplot(x='Team', y='Wins', data=Total_Matches_Won)
# plt.xlabel('Team')
# plt.ylabel('Wins')
# plt.title('Total Matches Won by Teams')
# plt.xticks(rotation=90)
# plt.show()

# %%
#Creates a Series 
toss_ser =matches_df['TossWinner'].value_counts()
#Creates an empty DF with columns for team name and number of wins
toss_df = pd.DataFrame(columns=["Team", "Wins"])
for items in toss_ser.iteritems():
    temp_df3 = pd.DataFrame({
        'Team':[items[0]],
        'Wins':[items[1]]
    })
#Creates a DF that contains one row for each team that won the toss accross all matches
    toss_df = toss_df.append(temp_df3, ignore_index=True)

# %% [markdown]
# <center>
# <img src="images/cointoss.gif" width=300 />
# </center>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set figure size
plt.figure(figsize=(14, 6))

# Plot the first bar chart
plt.subplot(1, 3, 1)
sns.barplot(x='Team', y='Wins', data=Total_Matches_Won)
plt.xlabel('Team')
plt.ylabel('Wins')
plt.title('Total Matches Won by Teams')
plt.xticks(rotation=90)

# Plot the second bar chart
plt.subplot(1, 3, 2)
plt.title("Teams Winning Number of Toss")
sns.barplot(x='Team', y='Wins', data=toss_df)
plt.xlabel('Team')
plt.ylabel('Wins')
plt.xticks(rotation=90)

plt.tight_layout()  # Add spacing between subplots
plt.show()

# %% [markdown]
# # Facts Observed:
# Mumbai Indians has won the most toss(till 2022) in IPL history. & MI has won highest number of matches too.
# All the top teams in IPL are successful in winning the toss as well.
# #Does winning the toss has any advantage? Lets check

# %%
#Analysing the relationshop between the toss winner and winning team
#Interating over each row of DF to count the number of times the team that won the toss also won the match
#Initializing the variables to 0 before the loop
win_count = 0
lost_count = 0
#Checking if the toss winner and winning team have the same value
for index, value in matches_df.iterrows():
#If yes, variable 'win_count' is incremented
    if(value['TossWinner']==value['WinningTeam']):
#         print(value['winner'])
        win_count += 1
#If no, then variable 'loss_count' is incremented
    elif (value['TossWinner'] != value['WinningTeam']):
        lost_count +=1

print(f'The number of times the team winning toss have won: {win_count}')
print(f'The number of times the team winning toss have lost: {lost_count}')
prob = win_count/len(matches_df)
print(f'The probability of winning if won the toss: {prob:.2f}')
# Out:
# The number of times the team winning toss have won: 489
# The number of times the team winning toss have lost: 461
# The probability of winning if won the toss: 0.51

# %% [markdown]
# Its almost 50 - 50.
# While winning the toss does provide a slight edge with a 1% higher chance of winning, it would be naive to consider it a significant advantage. In fact, there were 461 instances where the team that lost the toss still managed to win the game.

# %% [markdown]
# # What are the major victories in IPL? Is it better to defend or chase in IPL?
#
# <center>
# <img src="images/think.gif" width=300 />
# </center>

# %%
#Returns the number of rows in the DF
len(matches_df)
# Out:
# 950

# %%
#Analyzing the number of matches won while chasing versus defending
defend_win1 =matches_df[(matches_df['WonBy'] == 'Runs')]
# defend_win = defend_win.Margin.value_counts()
# print(defend_win.sort_values(ascending=True))
#Checking if the 'WonBy' column has the value 'Runs'
chase_win1 =matches_df[(matches_df['WonBy'] != 'Runs')]
print(f'matches won while chasing: {len(chase_win1)}')
print(f'matches won while defending: {len(defend_win1)}')
# Out:
# matches won while chasing: 527
# matches won while defending: 423

# %% [markdown]
# More matches were won while chasing, so if won a toss and decided to field first, higher chance of winning.  <br>
# But here is an example when defending team won by huge score!

# %%
#Analysing the margins of victory for matches that were won by defending
# defend_win = defend_win1.Margin.value_counts()
defend_win2 = defend_win1.Margin.value_counts().sort_index(ascending=False)
print(defend_win2)
#print(matches_df[matches_df['Margin'] == 140])
#print(matches_df[matches_df['Margin'] == 146][['Team1', 'Team2', 'TossWinner', 'TossDecision','WinningTeam','WonBy','Margin']])
matches_df[(matches_df['Margin'] == 146) & (matches_df['WonBy'] == 'Runs')][['Team1', 'Team2', 'TossWinner', 'TossDecision','WinningTeam','WonBy','Margin']]
# Out:
# 146.0     1
# 144.0     1
# 140.0     1
# 138.0     1
# 130.0     1
#          ..
# 5.0       8
# 4.0      13
# 3.0       7
# 2.0      10
# 1.0      11
# Name: Margin, Length: 94, dtype: int64
#                 Team1           Team2        TossWinner TossDecision  \
# 329  Delhi Daredevils  Mumbai Indians  Delhi Daredevils        field
#
#         WinningTeam WonBy  Margin
# 329  Mumbai Indians  Runs   146.0

# %% [markdown]
# ## Wohhooo this miracle happened in 2017!!
# <img src = 'images/Mumbai-Indians-2017.jpg' />
#
# The greatest victory in IPL on defending a total is for ***Mumbai Indians*** when they defeated ***Delhi Daredevils*** by 146 runs on 06 May 2017 at Feroz Shah Kotla stadium, Delhi.
# <br><br>

# %%
#Analysing the margins of victory for matches that were won by chasing
chase_win2 = chase_win1.Margin.value_counts().sort_index(ascending=False)
chase_win2
# Out:
# 10.0     15
# 9.0      44
# 8.0      69
# 7.0     102
# 6.0     104
# 5.0      90
# 4.0      49
# 3.0      25
# 2.0       8
# 1.0       3
# Name: Margin, dtype: int64

# %% [markdown]
# There have been ***15*** instances where the chasing team achieved the biggest victory by 10 wickets without losing any wickets while chasing a target.

# %%
#Filtering the DF to include only matches where the winning team won by 10 wicket
matches_df[(matches_df['Margin'] == 10) & (matches_df['WonBy'] == 'Wickets')] [['Team1', 'Team2', 'TossWinner', 'TossDecision','WinningTeam','WonBy','Margin']]
# Out:
#                            Team1                        Team2  \
# 118             Rajasthan Royals  Royal Challengers Bangalore
# 138               Mumbai Indians          Sunrisers Hyderabad
# 153          Chennai Super Kings               Mumbai Indians
# 176              Kings XI Punjab          Chennai Super Kings
# 266              Kings XI Punjab  Royal Challengers Bangalore
# 338              Kings XI Punjab             Delhi Daredevils
# 370                Gujarat Lions        Kolkata Knight Riders
# 418                Gujarat Lions          Sunrisers Hyderabad
# 467             Delhi Daredevils  Royal Challengers Bangalore
# 617              Kings XI Punjab          Chennai Super Kings
# 632             Rajasthan Royals               Mumbai Indians
# 710               Mumbai Indians             Rajasthan Royals
# 825  Royal Challengers Bangalore             Rajasthan Royals
# 889             Delhi Daredevils              Kings XI Punjab
# ...

# %%
#Creating a DF to store information about the margins of victory for matches that were won by chasing
chasing_win_df = pd.DataFrame(columns=['victory_margin', 'instances'])
#Iterating over each item in the 'chase_win2' series using the iterations() method
for items in chase_win2.iteritems():    
    temp_df7 = pd.DataFrame({
        'victory_margin': [items[0]],
        'instances': [items[1]]
    })
    chasing_win_df = chasing_win_df.append(temp_df7, ignore_index=True)

chasing_win_df
# Out:
#    victory_margin instances
# 0            10.0        15
# 1             9.0        44
# 2             8.0        69
# 3             7.0       102
# 4             6.0       104
# 5             5.0        90
# 6             4.0        49
# 7             3.0        25
# 8             2.0         8
# 9             1.0         3

# %%
#Creating a bar plot to visualize the number of instances of each margin of victory for matches that were won by chasing
plt.title('The IPL victories in numbers when chasing a total')
sns.barplot(x='victory_margin', y='instances', data=chasing_win_df);

# %% [markdown]
# ## Run distribution Per Year

# %%
#Converting the 'Date' column into a datetime format
matches_df['Season'] = pd.to_datetime(matches_df['Date']).dt.year

# %%
#Creating a DF to merge the 'matches_df' DF on the 'ID' column with the deliveries
batsmen = matches_df[['ID','Season']].merge(deliveries, left_on = 'ID', right_on = 'ID', how = 'left').drop('ID', axis = 1)
#Grouping the rows in the DF by 'Season'
Season=batsmen.groupby(['Season'])['total_run'].sum().reset_index()

# %%
#Creating a new DF by grouping 'batsmen' DF by 'Season and calculating the number of sixes hit in each season
Season_boundaries=batsmen.groupby("Season")["batsman_run"].agg(lambda x: (x==6).sum()).reset_index()
fours=batsmen.groupby("Season")["batsman_run"].agg(lambda x: (x==4).sum()).reset_index()
Season_boundaries=Season_boundaries.merge(fours,left_on='Season',right_on='Season',how='left')
Season_boundaries=Season_boundaries.rename(columns={'batsman_run_x':'6"s','batsman_run_y':'4"s'})

# %%
#Multipying the number of sixes and fours hit in each season by '6' and '4'
Season_boundaries['6"s'] = Season_boundaries['6"s']*6
Season_boundaries['4"s'] = Season_boundaries['4"s']*4
Season_boundaries['total_run'] = Season['total_run']

# %%
#Creating a stacked bar chart that shows the distribution of runs scored per year in the IPL
trace1 = go.Bar(
    x=Season_boundaries['Season'],
    y=Season_boundaries['total_run']-(Season_boundaries['6"s']+Season_boundaries['4"s']),
    marker = dict(line=dict(color='#000000', width=1)),
    name='Remaining runs',opacity=0.6)

trace2 = go.Bar(
    x=Season_boundaries['Season'],
    y=Season_boundaries['4"s'],
    marker = dict(line=dict(color='#000000', width=1)),
    name='Run by 4"s',opacity=0.7)

trace3 = go.Bar(
    x=Season_boundaries['Season'],
    y=Season_boundaries['6"s'],
    marker = dict(line=dict(color='#000000', width=1)),
    name='Run by 6"s',opacity=0.7)


data = [trace1, trace2, trace3]
layout = go.Layout(title="Run Distribution per year",barmode='stack',xaxis = dict(tickmode='linear',title="Year"),
                                    yaxis = dict(title= "Run Distribution"), plot_bgcolor='rgb(245,245,245)')

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="1fa52763-37ef-4924-b164-2248ae4cf49b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1fa52763-37ef-4924-b164-2248ae4cf49b")) {                    Plotly.newPlot(                        "1fa52763-37ef-4924-b164-2248ae4cf49b",                        [{"marker":{"line":{"color":"#000000","width":1}},"name":"Remaining runs","opacity":0.6,"x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[7387,8021,8525,9656,10411,10300,8389,7757,8496,8102,8061,8098,8644,8311,9943],"type":"bar"},{"marker":{"line":{"color":"#000000","width":1}},"name":"Run by 4\"s","opacity":0.7,"x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[6812,5284,6836,7664,7644,8216,62
# ...

# %% [markdown]
# Just slight increase in runs by boundaries over years

# %% [markdown]
# # Bowler Analysis

# %%
#Groups the deliveries by bowler
#Calculates their total runs given, number of balls bowled, and the number of overs bowled
bowlers=deliveries.groupby('bowler').sum().reset_index()
bowl=deliveries['bowler'].value_counts().reset_index()
bowlers=bowlers.merge(bowl,left_on='bowler',right_on='index',how='left')
bowlers=bowlers[['bowler_x','total_run','bowler_y']]
bowlers.rename({'bowler_x':'bowler','total_run':'runs_given','bowler_y':'balls'},axis=1,inplace=True)
bowlers['overs']=(bowlers['balls']//6)

# %%
#Creating a new column 'bowlers to the DF which counts the number of wickets taken by each bowler
dismissal_kinds = ["bowled", "caught", "lbw", "stumped", "caught and bowled", "hit wicket"]  
ct=deliveries[deliveries["kind"].isin(dismissal_kinds)]
ct=ct['bowler'].value_counts().reset_index()
bowlers=bowlers.merge(ct,left_on='bowler',right_on='index',how='left').dropna()
bowlers=bowlers[['bowler_x','runs_given','overs','bowler_y']]
bowlers.rename({'bowler_x':'bowler','bowler_y':'wickets'},axis=1,inplace=True)
bowlers['economy']=(bowlers['runs_given']/bowlers['overs'])

# %% [markdown]
# <img src = 'images/cleanbold.gif' align = 'left' width=500>
# <img src = 'images/bowl1.gif' align = 'right'>

# %%
#Sorts the bowlers datset
bowlers_top=bowlers.sort_values(by='runs_given',ascending=False)
bowlers_top=bowlers_top.head(20)

# %%
#Generate a scatter plot using the Plotly library in Python
#The scatter plot displays the top 20 wicket taking bowlers in cricket
trace = go.Scatter(y = bowlers_top['wickets'],x = bowlers_top['bowler'],mode='markers',
                   marker=dict(size= bowlers_top['wickets'].values,
                               color = bowlers_top['economy'].values,
                               colorscale='Viridis',
                               showscale=True,
                               colorbar = dict(title = 'Economy')),
                   text = bowlers['overs'].values)

data = [(trace)]

layout= go.Layout(autosize= True,
                  title= 'Top 20 Wicket Taking Bowlers',
                  hovermode= 'closest',
                  xaxis=dict(showgrid=False,zeroline=False,
                             showline=False),
                  yaxis=dict(title= 'Wickets Taken',ticklen= 5,
                             gridwidth= 2,showgrid=False,
                             zeroline=False,showline=False),
                  showlegend= False,plot_bgcolor='rgb(245,245,245)')

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="fad39102-c65f-4608-9ff5-9ab0047334f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fad39102-c65f-4608-9ff5-9ab0047334f7")) {                    Plotly.newPlot(                        "fad39102-c65f-4608-9ff5-9ab0047334f7",                        [{"marker":{"color":[6.859701492537313,8.080145719489982,7.927404718693285,7.5764272559852675,7.046391752577319,7.205673758865248,8.246938775510204,7.286231884057971,6.667235494880546,7.548979591836734,7.350840336134453,7.042424242424242,7.612756264236902,7.2517321016166285,7.634085213032582,8.354395604395604,8.36827195467422,7.546174142480211,8.687306501547988,7.985632183908046],"colorbar":{"title":{"text":"Economy"}},"colorscale":[[0.0,"#440154"],[0.111111111111
# ...

# %% [markdown]
# <img src = 'images/djbravo.gif'>

# %% [markdown]
# ## Purple Cap Holders

# %%
#Creating a list of all the possible dismissal types that are credited to the bowler
#Creates a DF that contains the top wicket-taking bowlers in each season of the cricket match
dismissal_kinds = ["bowled", "caught", "lbw", "stumped", "caught and bowled", "hit wicket"]  #since run-out is not creditted to the bowler
purple=deliveries[deliveries["kind"].isin(dismissal_kinds)]
purple=purple.merge(matches_df,left_on='ID',right_on='ID',how='outer')
purple=purple.groupby(['Season','bowler'])['kind'].count().reset_index()
purple=purple.sort_values('kind',ascending=False)
purple=purple.drop_duplicates('Season',keep='first').sort_values(by='Season')
purple.rename({'kind':'count_wickets'},axis=1,inplace=True)

# %%
#Creates a bar chart that shows the number of wickets taken by the leading wicket taker in each season of the cricket match
trace1 = go.Bar(x=purple['Season'].values,y=purple['count_wickets'].values,
                name='Total Matches',text=purple['bowler'].values,
                marker=dict(color='rgb(75,0,130)',
                            line=dict(color='#000000',width=1.5,)),
                opacity=0.4)

layout = go.Layout(title='Purple-Cap Holders',xaxis = dict(tickmode='linear',title="Year"),
                   yaxis=dict(title='Wickets'), plot_bgcolor='rgb(245,245,245)')

data=[trace1]
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="fe819684-8edf-482c-ba5d-d3e84c80d201" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe819684-8edf-482c-ba5d-d3e84c80d201")) {                    Plotly.newPlot(                        "fe819684-8edf-482c-ba5d-d3e84c80d201",                        [{"marker":{"color":"rgb(75,0,130)","line":{"color":"#000000","width":1.5}},"name":"Total Matches","opacity":0.4,"text":["Sohail Tanvir","RP Singh","PP Ojha","SL Malinga","M Morkel","DJ Bravo","MM Sharma","DJ Bravo","B Kumar","B Kumar","AJ Tye","K Rabada","K Rabada","HV Patel","YS Chahal"],"x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[22,23,21,28,25,32,23,26,23,26,24,26,32,32,27],"type":"bar"}],                        {"plot
# ...

# %% [markdown]
# <img src = 'images/purplecap.jpg'>

# %% [markdown]
# ## Top 10 Bowlers

# %%
#Calculates the top 10 wicket taking bowlers by grouping the 'deliveries' DF and counting the number of wickets taken by each bowler
bowling_wickets=deliveries[deliveries['kind']!='run out']
bowling_tot=bowling_wickets.groupby('bowler').apply(lambda x:x['kind'].dropna()).reset_index(name='Wickets')
bowling_wick_count=bowling_tot.groupby('bowler').count().reset_index()
bowling_top=bowling_wick_count.sort_values(by='Wickets',ascending=False)
top_bowlers=bowling_top.loc[:,['bowler','Wickets']][0:10]

# %%
#Creates a line plot for the top 10 wicket taking bowlers in IPL
trace1 = go.Scatter(
    x = top_bowlers['bowler'].values,
    y = top_bowlers['Wickets'].values,
    mode = 'lines+markers',
)

layout = go.Layout(title="Top 10 Bowlers in IPL- Seasons 2008-2022",
                   xaxis=dict(title="TOP 10 Bowlers"),
                   yaxis=dict(title="Wickets Taken"),
                  plot_bgcolor='rgb(245,245,245)')


data = [trace1]

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="15ffaa0a-cb21-4614-8ead-3c08c91f83fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15ffaa0a-cb21-4614-8ead-3c08c91f83fb")) {                    Plotly.newPlot(                        "15ffaa0a-cb21-4614-8ead-3c08c91f83fb",                        [{"mode":"lines+markers","x":["DJ Bravo","SL Malinga","YS Chahal","A Mishra","R Ashwin","PP Chawla","B Kumar","SP Narine","Harbhajan Singh","JJ Bumrah"],"y":[183,170,166,166,157,157,154,152,150,148],"type":"scatter"}],                        {"plot_bgcolor":"rgb(245,245,245)","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2
# ...

# %% [markdown]
# ## Top 10 Bowling Performances till 2022

# %%
#Groups the deliveries by the match ID and bowler and then counts the number of wickets taken by each bowler in each match
match_bowling_tot=bowling_wickets.groupby(['ID','bowler']).apply(lambda x:x['kind'].dropna()).reset_index(name='Wickets')
match_bowling_wick_count=match_bowling_tot.groupby(['ID','bowler']).count().reset_index()
match_bowling_top=match_bowling_wick_count.sort_values(by='Wickets',ascending=False)
match_top_bowlers=match_bowling_top.loc[:,['ID','bowler','Wickets']][0:10] 
match_bowling_runs=deliveries.groupby(['ID','bowler']).apply(lambda x:np.sum(x['total_run'])).reset_index(name='Runs Conceeded')
match_bowler_performance=pd.merge(match_top_bowlers,match_bowling_runs,how='inner',left_on=['ID','bowler'],right_on=['ID','bowler'])
match_bowler_performance['Runs per Wicket']=match_bowler_performance['Runs Conceeded']/match_bowler_performance['Wickets']
bowler_innings=pd.merge(match_bowler_performance, deliveries,how='inner',left_on=['ID','bowler'],right_on=['ID','bowler'])
bowler_innings_req=bowler_innings.iloc[:,1:8]
bowler_innings_req_2=bowler_innings_req.drop_duplicates()
x=bowler_innings_req_2['bowler']
y1=bowler_innings_req_2['Wickets']
y2=bowler_innings_req_2['Runs per Wicket']

# %%
'''Creates a plot to visualize the best bowling performances in a match 
in terms of runs conceded per wicket taken and the number of wickets 
taken by the bowler'''

trace1 = go.Scatter(
    x = x,
    y = y1,
    mode = 'markers',
    name="Wickets"
)

trace2 = go.Scatter(
    x = x,
    y = y2,
    mode = 'lines+markers',
    name="Run Per Wicket"
)

layout = go.Layout(title="IPL Best bowling performances in a Match",
                   xaxis=dict(title="Top Bowlers"),
                   yaxis=dict(title="Runs per Wicket/Wickets"),
                  plot_bgcolor='rgb(245,245,245)')


data = [trace1, trace2]


fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="d45d6120-6584-4361-a634-e299aa0c5804" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d45d6120-6584-4361-a634-e299aa0c5804")) {                    Plotly.newPlot(                        "d45d6120-6584-4361-a634-e299aa0c5804",                        [{"mode":"markers","name":"Wickets","x":["AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","AS Joseph","A Zampa","A Zampa","A Zampa","A Zampa","A Zampa","A Zampa","A Zampa","A Zampa","A Zampa","A Zampa","A Zampa","A Zampa","A Zampa","A Zampa"
# ...

# %% [markdown]
# # Batsman Analysis

# %%
#Used to compute various batting statistics for each batsmen in the IPL
df_strike_rate = deliveries.groupby(['batter']).agg({'ballnumber':'count','batsman_run':'mean'}).sort_values(by='batsman_run',ascending=False)
df_strike_rate.rename(columns ={'batsman_run' : 'strike rate'}, inplace=True)
df_runs_per_match = deliveries.groupby(['batter','ID']).agg({'batsman_run':'sum'})
df_total_runs = df_runs_per_match.groupby(['batter']).agg({'sum' ,'mean','count'})
df_total_runs.rename(columns ={'sum' : 'batsman_run','count' : 'match count','mean' :'average score'}, inplace=True)
df_total_runs.columns = df_total_runs.columns.droplevel()
df_sixes = deliveries[['batter','batsman_run']][deliveries.batsman_run==6].groupby(['batter']).agg({'batsman_run':'count'})
df_four = deliveries[['batter','batsman_run']][deliveries.batsman_run==4].groupby(['batter']).agg({'batsman_run':'count'})
'''The resulting DF contains the stike rate, total runs scored, 
average score per match, number of sixes, and number of fours for 
each batsmen in the IPL'''
df_batsman_stat = pd.merge(pd.merge(pd.merge(df_strike_rate,df_total_runs, left_index=True, right_index=True),
                                    df_sixes, left_index=True, right_index=True),df_four, left_index=True, right_index=True)

# %%
df_batsman_stat.rename(columns = {'ballnumber' : 'ballnumber', 'strike rate':'strike_rate','batsman_run' : 'batsman_run',
                                  'match count' : 'match_count','average score' : 'average_score' ,'batsman_run_x' :'six',
                                  'batsman_run_y':'four'},inplace=True)
df_batsman_stat['strike_rate'] = df_batsman_stat['strike_rate']*100
df_batsman_stat.sort_values(by='batsman_run',ascending=False,inplace=True)
#df_batsman_stat.sort_values(by='batsman_run',ascending=False)
df_batsman_stat.reset_index(inplace=True)

# %% [markdown]
# <img src = 'images/bat2.jpg' width=500>

# %% [markdown]
# Highest Average and Strike rate for >50 Matches

# %%
'''Calculates various statistics for batsmen based on IPL matches'''
average_score=df_batsman_stat.sort_values(by='average_score',ascending=False)
average_score=average_score[average_score['match_count']>50].head(10)
#Filters the batsmen
strike_rate=df_batsman_stat.sort_values(by='strike_rate',ascending=False)
strike_rate=strike_rate[strike_rate['match_count']>50].head(10)

# %%
from plotly import tools

# %%
'''Creates a horizontal bar chart that shows the top 10 batsmen in terms of 
average score and strike rate who have played more than 50 matches'''

trace1 = go.Bar(x=average_score['batter'],y=average_score['average_score'],
                name='Average Score',marker=dict(color='gold', line=dict(color='#000000', width=1.5)),opacity=0.6,showlegend=False)

trace2 = go.Bar(x=strike_rate['batter'],y=strike_rate['strike_rate'],
                name='Strike Rate',marker=dict(color='brown', line=dict(color='#000000', width=1.5)),opacity=0.6,showlegend=False)

fig = tools.make_subplots(rows=1, cols=2, subplot_titles=('Highest Average Score','Highest Strike Rate'))

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

fig['layout']['xaxis1'].update(title='Player')
fig['layout']['xaxis2'].update(title='Player')

iplot(fig)
# Out:
# C:\Users\mitta\AppData\Roaming\Python\Python310\site-packages\plotly\tools.py:460: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
# ...

# %% [markdown]
# <img src = 'images/klrahul.gif' align = 'left' width = 500>
# <img src = 'images/russell.gif' align = 'right' width = 400>

# %% [markdown]
# ## Top 20 Batsman

# %%
#Create a new DF which includes the top 20 batsmen based on their performance
top_df_batsman=df_batsman_stat.head(20)
top_df_batsman.head(5)
# Out:
#       batter  ballnumber  strike_rate  match_count   six  average_score  four  \
# 0   S Dhawan        5083   122.840842          205  6244      30.458537   137
# 1    V Kohli        5266   125.977972          215  6634      30.855814   219
# 2  DA Warner        4313   136.401577          162  5883      36.314815   216
# 3  RG Sharma        4632   126.964594          221  5881      26.610860   241
# 4   SK Raina        4177   132.535312          200  5536      27.680000   204
#
#    batsman_run
# 0          701
# 1          581
# 2          577
# 3          519
# 4          506

# %% [markdown]
# <img src = 'images/dhawan.jpeg'>

# %%
 #creating a scatter plot using the plotly library
    '''x-axis represents the batters' names, the y-axis represents the number of matches played by each batter,
    and the size of the marker represents the average score of the batter.'''
    data=[{"y": top_df_batsman.match_count,
        "x": top_df_batsman.batter,
        "mode":"markers",
        "marker":{"color":top_df_batsman.six,"size" :top_df_batsman.average_score,'showscale': True},
        "text":top_df_batsman.batter }]

iplot(data)
# Out:
# <div>                            <div id="d42745e9-e90f-47c3-a138-4760ca67a6bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d42745e9-e90f-47c3-a138-4760ca67a6bf")) {                    Plotly.newPlot(                        "d42745e9-e90f-47c3-a138-4760ca67a6bf",                        [{"marker":{"color":[6244,6634,5883,5881,5536,4217,4954,4074,4377,5181,4997,3880,2848,4190,4978,2728,3895,3657,3403,2334],"showscale":true,"size":[30.458536585365852,30.855813953488372,36.31481481481482,26.61085972850679,27.68,27.927152317880793,25.14720812182741,27.527027027027028,21.144927536231883,30.476470588235294,35.43971631205674,27.5177304964539,20.941176470588236,24.21965317919075,24.28292682926829,26.23076923076923,39.343434343434346,24.70945945945946,31
# ...

# %% [markdown]
# ***Shikhar Dhawan*** has highest total runs across all seasons. <br>
# **Virat Kohli** is just few runs behind with the second spot
#
# Average Score and 6"s by Parthiv Patel is lowest among top 20 batsmen

# %% [markdown]
# <img src = 'images/kohli.gif'>

# %% [markdown]
#  ## Top 10 Batsman in each run category

# %%
'''creates a dataframe toppers that shows how many times 
each batter has scored a particular number of runs.'''
toppers=deliveries.groupby(['batter','batsman_run'])['total_run'].count().reset_index()
toppers=toppers.pivot('batter','batsman_run','total_run')
toppers.reset_index(inplace=True)

# %%
top_6 = toppers.sort_values(6,ascending=False).head(10)
top_4 = toppers.sort_values(4,ascending=False).head(10)
top_2 = toppers.sort_values(2,ascending=False).head(10)
top_1 = toppers.sort_values(1,ascending=False).head(10)

# %%
''' visualizing the top scorers in each category and the top batsmen
based on their average score and strike rate.'''
trace1 = go.Scatter(x=top_6.batter,y =top_6[6],name='6"s',marker =dict(color= "blue",size = 9),line=dict(width=2,dash='dash'))
trace2 = go.Scatter(x=top_4.batter,y = top_4[4],name='4"s',marker =dict(color= "orange",size = 9),line=dict(width=2,dash='longdash'))
trace3 = go.Scatter(x=top_2.batter,y = top_2[2],name='2"s',marker =dict(color= "green",size = 9),line=dict(width=2,dash='dashdot'))
trace4 = go.Scatter(x=top_1.batter,y = top_1[1],name='1"s',marker =dict(color= "red",size = 9),line=dict(width=2,dash='longdashdot'))

fig = tools.make_subplots(rows=4, cols=1, subplot_titles=('Top 6"s Scorer','Top 4"s Scorer',
                                                          'Top 2"s Scorer','Top 1"s Scorer'))

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 2, 1)
fig.append_trace(trace3, 3, 1)
fig.append_trace(trace4, 4, 1)

fig['layout'].update(title='Top Scorer in each Category',showlegend=False, plot_bgcolor='rgb(245,245,245)')
iplot(fig)
# Out:
# C:\Users\mitta\AppData\Roaming\Python\Python310\site-packages\plotly\tools.py:460: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
# ...

# %% [markdown]
# <img src = 'images/gayle.gif'>

# %% [markdown]
# ## Orange Cap Holders

# %%
'''contains the highest scorer of each season based on 
total runs scored by a batsman in that season.'''
orange=matches_df[['ID','Season']]
orange=orange.merge(deliveries,left_on='ID',right_on='ID',how='left')
orange=orange.groupby(['Season','batter'])['batsman_run'].sum().reset_index()
orange=orange.sort_values('batsman_run',ascending=0)
orange=orange.drop_duplicates(subset=["Season"],keep="first")
#orange.sort_values(by='season')

# %%
'''bar chart shows the top run-scorers for each season of the IPL, 
represented by the Orange Cap holders. '''
data = [go.Bar(x=orange['Season'].values,y=orange['batsman_run'].values,
                name='Total Matches',text=orange['batter'].values,
                marker=dict(color='rgb(255,140,0)',
                            line=dict(color='rgb(8,48,107)',width=1.5,)),opacity=0.7)]

layout = go.Layout(title='Orange-Cap Holders',xaxis = dict(tickmode='linear',title="Year"),
                   yaxis=dict(title='Runs'), plot_bgcolor='rgb(245,245,245)')

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="2b45c7fc-70a7-46ab-ab7b-d4db0ce2a3f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b45c7fc-70a7-46ab-ab7b-d4db0ce2a3f3")) {                    Plotly.newPlot(                        "2b45c7fc-70a7-46ab-ab7b-d4db0ce2a3f3",                        [{"marker":{"color":"rgb(255,140,0)","line":{"color":"rgb(8,48,107)","width":1.5}},"name":"Total Matches","opacity":0.7,"text":["V Kohli","JC Buttler","KS Williamson","MEK Hussey","CH Gayle","DA Warner","KL Rahul","RV Uthappa","DA Warner","RD Gaikwad","SR Tendulkar","SE Marsh","CH Gayle","ML Hayden","DA Warner"],"x":[2016,2022,2018,2013,2012,2019,2020,2014,2017,2021,2010,2008,2011,2009,2015],"y":[973,863,735,733,733,692,676,660,641,635,618,616,608,572,562],"type":
# ...

# %% [markdown]
# ***Virat kohli*** owned Orange cap with highesr 973 runs in 2016
#
# <img src = 'images/orange.gif'>

# %%
#Displaying the columns 
print(matches_df.columns)
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'Player_of_Match', 'Team1Players', 'Team2Players',
#        'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
match_df_int = matches_df.copy()
match_df_int
# Out:
#           ID        City        Date  Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29    2022        Final
# 1    1312199   Ahmedabad  2022-05-27    2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25    2022   Eliminator
# 3    1312197     Kolkata  2022-05-24    2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22    2022           70
# ..       ...         ...         ...     ...          ...
# 945   335986     Kolkata  2008-04-20    2008            4
# 946   335985      Mumbai  2008-04-20    2008            5
# 947   335984       Delhi  2008-04-19    2008            3
# 948   335983  Chandigarh  2008-04-19    2008            2
# 949   335982   Bangalore  2008-04-18    2008            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
#here team names are in string format. generally computers and machine learning works on integer values so we need 
#to impute them by converting into dictionary

team_encodings={
    'Mumbai Indians': 1, 
    'Kolkata Knight Riders': 2, 
    'Royal Challengers Bangalore': 3, 
    'Deccan Chargers': 4, 
    'Chennai Super Kings': 5, 
    'Rajasthan Royals': 6, 
    'Delhi Daredevils': 7, 
    'Gujarat Lions': 8, 
    'Kings XI Punjab': 9, 
    'Sunrisers Hyderabad': 10, 
    'Rising Pune Supergiants': 11, 
    'Kochi Tuskers Kerala': 12,
    'Pune Warriors': 13, 
    'Delhi Capitals': 14, 
    'Lucknow Super Giants': 15, 
    'Punjab Kings' :16,
    'Gujarat Titans' :17,
    'Draw':18
        
}

team_encode_dict={
    'Team1': team_encodings,
    'Team2': team_encodings,
    'TossWinner': team_encodings,
    'WinningTeam': team_encodings
    
}

match_df_int.replace(team_encode_dict,inplace=True)
match_df_int.head(2)
# Out:
#         ID       City        Date  Season  MatchNumber  Team1  Team2  \
# 0  1312200  Ahmedabad  2022-05-29    2022        Final      6     17
# 1  1312199  Ahmedabad  2022-05-27    2022  Qualifier 2      3      6
#
#                               Venue  TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad           6          bat         N
# 1  Narendra Modi Stadium, Ahmedabad           6        field         N
#
#    WinningTeam    WonBy  Margin Player_of_Match  \
# 0           17  Wickets     7.0       HH Pandya
# 1            6  Wickets     7.0      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon
# ...

# %%
#retrieves the encoding dictionary for the 'WinningTeam' column.
dicVal = team_encode_dict['WinningTeam']
train = match_df_int[['Team1','Team2','City','TossDecision','TossWinner','Venue','WinningTeam']]
train.head(5)
# Out:
#    Team1  Team2       City TossDecision  TossWinner  \
# 0      6     17  Ahmedabad          bat           6
# 1      3      6  Ahmedabad        field           6
# 2      3     15    Kolkata        field          15
# 3      6     17    Kolkata        field          17
# 4     10     16     Mumbai          bat          10
#
#                               Venue  WinningTeam
# 0  Narendra Modi Stadium, Ahmedabad           17
# 1  Narendra Modi Stadium, Ahmedabad            6
# 2                      Eden Gardens            3
# 3                      Eden Gardens           17
# 4                  Wankhede Stadium           16

# %%
# to show the first 10 rows of the DataFrame with the categorical columns encoded
df = pd.DataFrame(train)
var_mod = ['City','TossDecision','Venue']
le = LabelEncoder()
for i in var_mod:
    df[i] = le.fit_transform(df[i])
df.head(10)
# Out:
#    Team1  Team2  City  TossDecision  TossWinner  Venue  WinningTeam
# 0      6     17     1             0           6     18           17
# 1      3      6     1             1           6     18            6
# 2      3     15    22             1          15      8            3
# 3      6     17    22             1          17      8           17
# 4     10     16    23             0          10     35           16
# 5     14      1    23             1           1     35            1
# 6      5      6    23             0           5      2            6
# 7     17      3    23             0          17     35            3
# 8     15      2    25             0          15      5           15
# 9     10      1    23             1           1     35           10

# %%
'''Used to create the feature matrix X and the target vector y.'''
X = df[['Team1', 'Team2', 'TossDecision','TossWinner', 'Venue','City']]
y = df[['WinningTeam']]
sc = StandardScaler()
X = sc.fit_transform(X)
print (X)
# Out:
# [[ 0.01171857  2.76934267 -1.30635091  0.03096346 -0.03896078 -1.58780844]
#  [-0.74732493 -0.00291817  0.7654911   0.03096346 -0.03896078 -1.58780844]
#  [-0.74732493  2.26529524  0.7654911   2.31318437 -1.00283416  0.75705634]
#  ...
#  [ 0.26473306 -0.00291817 -1.30635091  0.03096346 -0.90644682 -0.58286639]
#  [ 0.77076206 -0.25494188 -1.30635091 -0.22261664  0.44297591 -0.91784707]
#  [-0.74732493 -1.01101302  0.7654911  -0.72977684 -0.32812279 -1.47614821]]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
#from xgboost import XGBClassifier
import numpy as np
'''
Trains and evaluates five different classification
models on the input data X and target variable y. 
To evaluate the performance of these five classification models
and determine which one performs best on the given dataset.
'''
logistic_model = LogisticRegression()
logistic_model.fit(X,y)
print("Logistic Regression accuracy: ",(logistic_model.score(X,y))*100)
Random_model = RandomForestClassifier()
Random_model.fit(X,y)
print("Random Forest accuracy: ", (Random_model.score(X,y))*100)
knn_model = KNeighborsClassifier()
knn_model.fit(X,y)
print("KNeighbor Classifier accuracy", (knn_model.score(X,y))*100)
NB_model = GaussianNB()
NB_model.fit(X,y)
print("Gaussion Navie Bayis accuracy: " ,(NB_model.score(X,y))*100)
decision_model = DecisionTreeClassifier()
decision_model.fit(X,y)
print("Decision Tree Classifier accuracy: ", (decision_model.score(X,y))*100)
# Out:
# Logistic Regression accuracy:  28.10526315789474
# Random Forest accuracy:  89.6842105263158
# KNeighbor Classifier accuracy 53.05263157894737
# Gaussion Navie Bayis accuracy:  12.842105263157894
# Decision Tree Classifier accuracy:  89.6842105263158

# %%
#sample prediction
'''using the trained Random Forest classifier model to predict the winner of
a hypothetical match between "Rajasthan Royals" and "Gujarat Titans". 
Input data is first converted to a NumPy array and then passed to the
Random Forest classifier model's predict() method to predict the winner'''
team1='Rajasthan Royals'
team2='Gujarat Titans'
toss_winner='Rajasthan Royals'
inp = [team_encode_dict['Team1'][team1],team_encode_dict['Team2'][team2],0,team_encode_dict['TossWinner'][toss_winner],18,1]
print(inp)
inp = np.array(inp).reshape((1, -1))
print(inp)
#sc.fit_transform(inp)
output=Random_model.predict(inp)
print(output)
print(f"The winner would be: {list(team_encodings.keys())[list(team_encode_dict['Team1'].values()).index(output)]}")
#'Team1', 'Team2', 'TossDecision','TossWinner', 'Venue','City'
# Out:
# [6, 17, 0, 6, 18, 1]
# [[ 6 17  0  6 18  1]]
# [17]
# The winner would be: Gujarat Titans
